# %%
# %load_ext autoreload
# %autoreload 2

# %%
import re
import json
from tf.app import use
from tf.convert.watm import WATM, WATMS
# from watm import WATM, WATMS

# %%
BACKEND = "gitlab.huc.knaw.nl"
ORG = "translatin"
REPO = "corpus"

REPO_DIR = f"~/{BACKEND}/{ORG}/{REPO}"

# %% [markdown]
# # WATM
#
# We make an export of the TransLatin documents to WATM, the suite of systems developed by Team Text for
# serving text plus annotations over the web.
#
# WATM = Web Annotation Model for Text and consists (currently) of TextRepo, AnnoRepo, Broccoli, and TextAnnoViz.
#
# The input data is given by a Text-Fabric dataset, which is in turn derived from TEI files managed by the
# Huygens institute.

# %% [markdown]
# # Generate plain text
#
# The TransLatin corpus consists of several *manifestation* documents, called `Mxx` where `xx` is some integer.
# For each separate `Mxx` document we have a TF dataset in directory `tf/Mxx`.
#
# The process of generating WATM is done for each `Mxx` document separately.
#
# We generate a plain text of each TF corpus.
# This will produce a text and annotation file in directory `watm/Mxx`:
#
# * `text.json`: with the text segments in an array;
# * `anno.json`: all generated annotations
#
# ## Format of the text file
#
# A JSON file with the following structure:
#
# ```
# {
#   "_ordered_segments": [
#     "word1 ",
#     "word2 ",
#     ...
#   ]
# }
# ```
# * each item in `_ordered_segments` corresponds to one word,
# * the item contains the text of the word plus the subsequent interword material;
# * we skip all material inside the TEI-header;
#
# ## Format of the annotation file
#
# A JSON file with the following structure:
#
# ```
# {
#  "a000nnn": [
#   "kind",
#   "namespace",
#   "body",
#   "bbb-eee"
#  ],{
#  ...
# }
# ```
# * it is a big dict, keyed by annotation ids
# * the values consist of the annotation data, divided in the following fields:
#
# * `kind`: the kind of annotation
#   * `element`: targets the text location where an object occurs, the body is the kind of object;
#   * `attribute`: targets an property, the body has the shape *name*`=`*value*,
#     the name and value of the property in question;
#   * `node`: targets an individual token or object, the body is the TF node of that token/object;
#   * `edge`: targets two node annotations, the body has the shape
#     `*name* or `*name*`=`*value*,
#     where *name* is the name of the edge and *value* is the label of the edge if the edge has a label;
#
# * `namespace`: the namespace of the annotation; an indicator where the information comes from. Possible values:
#   * `pagexml`: attribute comes
#     from the PageXML, possibly indirectly, e.g. `h`, `w`, `x`, `y`
#   * `tf`: attribute is primarily for the sake of the TF encoding
#   * `nlp`: attribute is linguistic, e.g. `str`, which is the string value of a token.
#
# * `body`: the body of an annotation (probably the *kind* and *body* fields together will make up the body
#   of the resulting web annotation);
#
# * `target`: a string, of the following kinds:
#
#   * **single** this is a target pointing to a single thing, either:
#
#     * `bbb-eee` a range of text segments in the `_ordered_segments`;
#     * an annotation id
#
#   * **double** this is a target pointing to two things:
#     * `fff->ttt` where `fff` is a "from" target and `ttt` is a "to" target;
#       both targets can vary independently between a range and an annotation id.

# %% [markdown]
# # Remarks
#
# ## Tokens
#
# The base type is `token`.
#
# Tokens have the attributes `str` and `after`, both may be empty.
#
# * `str` is the *logical* string value of a token, `after` is empty or a space:
#   what comes after the token before the next token.
# * `rstr` is the raw string value of a token, when it deviates from the logical value.
#
# Example
#
# token | 1 | 2 | 3 | 4 | 5
# --- | --- | --- | --- | --- | ---
# rstr | empty | `efflagitan` | `¬` | `do` | empty
# str | `improbè` | `efflagitando` | empty | empty | `tandem`

# %% [markdown]
# # Generate

# %%
W = WATMS(ORG, REPO, BACKEND, "pagexml", skipMeta=False)
# Out:
# Found 68 docs in ~/gitlab.huc.knaw.nl/translatin/corpus/tf

# %%
# W.produce(doc="M38")
W.produce()
# Out:
#    M6 ...
# <style>tr.tf.ltr, td.tf.ltr, th.tf.ltr { text-align: left ! important;}
# tr.tf.rtl, td.tf.rtl, th.tf.rtl { text-align: right ! important;}
# @font-face {
#   font-family: "Gentium Plus";
#   src: local('Gentium Plus'), local('GentiumPlus'),
#     url('/browser/static/fonts/GentiumPlus-R.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/GentiumPlus-R.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Ezra SIL";
#   src: local('Ezra SIL'), local('EzraSIL'),
#     url('/browser/static/fonts/SILEOT.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/SILEOT.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "SBL Hebrew";
#   src: local('SBL Hebrew'), local('SBLHebrew'),
#     url('/browser/static/fonts/SBL_Hbrw.woff') format('woff'),
# ...

# %% [markdown]
# # Test
#
# We test the correctness and completeness of the text/annotations w.r.t. the TF dataset.
#
# We do so only for a single document.

# %%
A = use(f"{ORG}/{REPO}:clone", relative="tf/M95", checkout="clone", backend=BACKEND, hoist=globals())
# Out:
# **Locating corpus resources ...**
# <b title="local github">app:</b> <span title="repo clone offline under /Users/me/gitlab.huc.knaw.nl">~/gitlab.huc.knaw.nl/translatin/corpus/app</span>
# <b title="local github">data:</b> <span title="repo clone offline under /Users/me/gitlab.huc.knaw.nl">~/gitlab.huc.knaw.nl/translatin/corpus/tf/M95/0.1</span>
#             <b>TF:</b> <a target="_blank" href="https://annotation.github.io/text-fabric/tf/cheatsheet.html" title="text-fabric api">TF API 12.2.10</a>, <a target="_blank" href="https://gitlab.huc.knaw.nl/translatin/corpus/blob/main/app" title="translatin/corpus app">translatin/corpus/app  v3</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/tf/about/searchusage.html" title="Search Templates Introduction and Reference">Search Reference</a><br>
# ...

# %%
skipMeta = False
WA = WATM(A, "pagexml", skipMeta=skipMeta)
WA.makeText()
WA.makeAnno()
WA.writeAll()
# Out:
# Text file:   17746 segments to ~/gitlab.huc.knaw.nl/translatin/corpus/watm/0.1/M95/text.json
#  46071 annotations written to ~/gitlab.huc.knaw.nl/translatin/corpus/watm/0.1/M95/anno-1.json
# Anno files:   46071 annotations to 1 files

# %%
WA.testAll()
# Out:
# Testing the text ...
# 	TF:  17746
# 	WA:  17746
# OK - Same number of tokens
# 	TF: ¶ Typographus Lector ... zed by Google π F
# 	WA: ¶ Typographus Lector ... zed by Google π F
# OK - Same text
# Testing the elements ...
# 	TF:   2822
# 	WA:   2822
# OK - Same number of elements as nodes
# 	TF:      0
# 	WA:      0
# OK - Same number of processing instructions
# 	20568 element annotations
# 	Element :  2822 x
# 	Pi      :     0 x
# 	Other   : 43249 x
# 	Good    :  2822 x
# 	Wrong   :     0 x
# 	Unmapped:     0 x
# OK - All element annotations OK
# Testing the attributes ...
# 	22681 attribute values
# 	Good:     22681 x
# 	Wrong:        0 x
# OK - annotations consistent with features
# 	WA attributes: 22681
# 	TF attributes: 22681
# OK - annotations complete w.r.t. features
# Testing the format attributes ...
# 	0 format values
# 	formatting attributes:
# 	Good:         0 x
# 	Wrong:        0 x
# OK - format annotations consistent with features
# 	WA format attributes: 0
# ...
